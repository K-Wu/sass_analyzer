# %%
# %matplotlib inline
import os
os.chdir(os.path.abspath(os.path.join(os.getcwd(), '..','..')))
import sass_analyzer

# %%
# %matplotlib inline
from sass_analyzer.visualizer.templates import roofline
fig=roofline.plot_roofline_model(2000.0,20000.0,10.0,15000.0)
